# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tqdm

tqdm.tqdm.pandas()
import io
import gzip
import pytricia

# %% [markdown]
# # Question 1

# %%
df = pd.read_csv('data/processed/volume_by_protocol_port.csv')

print(df.groupby(['Protocol'])[['RelativeCount', 'RelativeVolume']].sum().reset_index().sort_values('RelativeVolume', ascending=False).head(20).style.to_latex())
print(df.groupby(['Protocol', 'Port'])[['RelativeCount', 'RelativeVolume']].sum().reset_index().sort_values('RelativeVolume', ascending=False).head(20).style.to_latex())
# Out:
# \begin{tabular}{llrr}
#  & Protocol & RelativeCount & RelativeVolume \\
# 6 & UDP & 0.584377 & 0.700904 \\
# 5 & TCP & 0.407300 & 0.289160 \\
# 1 & ICMPv4 & 0.003145 & 0.002443 \\
# 7 & UnknownIPProtocol & 0.000081 & 0.000056 \\
# 0 & GRE & 0.000000 & 0.000044 \\
# 3 & IPv6 & 0.000001 & 0.000001 \\
# 4 & IPv6HopByHop & 0.000001 & 0.000001 \\
# 2 & IGMP & 0.000000 & 0.000000 \\
# \end{tabular}
#
# \begin{tabular}{llrrr}
#  & Protocol & Port & RelativeCount & RelativeVolume \\
# 72664 & UDP & 53 & 0.550430 & 0.625467 \\
# 7198 & TCP & 23 & 0.045570 & 0.031654 \\
# 72974 & UDP & 5060 & 0.002901 & 0.013837 \\
# 13553 & TCP & 6379 & 0.014232 & 0.012064 \\
# 7197 & TCP & 22 & 0.016018 & 0.011441 \\
# 15617 & TCP & 8443 & 0.007263 & 0.005039 \\
# 7200 & TCP & 25 & 0.005479 & 0.004621 \\
# 7255 & TCP & 80 & 0.005250 & 0.004273 \\
# 12729 & TCP & 5555 & 0.004631 & 0.003374 \\
# 72693 & UDP & 443 & 0.000241 & 0.003104 \\
# 10564 & TCP & 3389 & 0.003963 & 0.002776 \\
# 72895 & UDP & 3702 & 0.003255 & 0.002614 \\
# 7256 & TCP & 81 & 0.003463 & 0.002409 \\
# 7618 & TCP & 443 & 0.003100 & 0.002252 \\
# 7169 & ICMPv4 & 2048 & 0.002965 & 0.002244 \\
# 15254 & TCP & 8080 & 0.003122 & 0.002204 \\
# 7228 & TCP & 53 & 0.002528 & 0.002058 \\
# 7620 & TCP & 445 & 0.002638 & 0.001972 \\
# 72673 & UDP & 123 & 0.001129 & 0.001675 \\
# 72643 & UDP & -1 & 0.000091 & 0.001479 \\
# \end{tabular}

# %% [markdown]
# # Question 2

# %%
as_numbers = io.StringIO()
as_org = io.StringIO()

with gzip.open('data/20230101.as-org2info.txt.gz') as f:
    while (line:=f.readline().decode('utf-8')):
        if 'format:' in line:
            as_org.write(line.replace('# format:', ''))
            break

    while (line:=f.readline().decode('utf-8')):
        if 'format:' in line:
            as_numbers.write(line.replace('# format:', ''))
            break
        as_org.write(line)

    while (line:=f.readline().decode('utf-8')):
        as_numbers.write(line)

    as_org.seek(0)
    as_numbers.seek(0)

as_orgs = pd.read_csv(as_org, delimiter='|')
as_numbers = pd.read_csv(as_numbers, delimiter='|')

as_org_data = as_orgs.merge(as_numbers, on='org_id', suffixes=['_org', '_number'])

print('loaded orgs')
df = pd.read_csv('data/processed/volume_by_source_as.csv').dropna()

df['SrcASN'] = df.SrcASN.str.split(',|_', regex=True).str[0].dropna().astype(int)
df.merge(as_org_data[['aut', 'org_name', 'country']], left_on='SrcASN', right_on='aut').drop(columns='aut').head(10)
# Out:
# loaded orgs
#    SrcASN    Count     Volume  RelativeCount  RelativeVolume  \
# 0   24560  8903109  879783558       0.261711        0.298629
# 1    9498  3447851  328159979       0.101351        0.111389
# 2   55836  3423046  339005780       0.100622        0.115070
# 3  202425  1984671  120963113       0.058340        0.041059
# 4   16509  1490310  136564084       0.043808        0.046355
# 5   16509        9        540       0.000000        0.000000
# 6   14061  1153173   73406305       0.033898        0.024917
# 7   57523   563559   33813540       0.016566        0.011477
# 8  398324   556001   33955571       0.016344        0.011526
# 9   44446   512755   30765300       0.015073        0.010443
#
#                              org_name country
# 0               Bharti Airtel Limited      IN
# 1               Bharti Airtel Limited      IN
# 2       Reliance Jio Infocomm Limited      IN
# 3                       IP Volume inc      SC
# 4                    Amazon.com, Inc.      US
# 5                    Amazon.com, Inc.      US
# 6                   DigitalOcean, LLC      US
# 7  Chang Way Technologies Co. Limited      HK
# 8                        Censys, Inc.      US
# 9                     OOO SibirInvest      RU

# %%
df = pd.read_csv('data/processed/volume_by_source_country.csv').dropna()
df
# df['SrcASN'] = df.SrcASN.str.split(',|_', regex=True).str[0].dropna().astype(int)
# df.merge(as_org_data[['aut', 'org_name', 'country']], left_on='SrcASN', right_on='aut').drop(columns='aut').head(10)
# Out:
#     NetacqCountry MaxmindCountry     Count      Volume  RelativeCount  \
# 0              in             IN  16483013  1609535277       0.484526
# 1              us             US   4240262   305002343       0.124644
# 2              nl             NL   1852106   115232548       0.054443
# 3              cn             CN   1609621   110511283       0.047316
# 4              ru             RU   1305499    80202490       0.038376
# ..            ...            ...       ...         ...            ...
# 538            cz             GB         1          60       0.000000
# 539            bw             ZA         1         240       0.000000
# 540            eu             TR         1          66       0.000000
# 541            nl             PL         1          71       0.000000
# 542            fr             YT         1          60       0.000000
#
#      RelativeVolume
# 0          0.546333
# 1          0.103528
# 2          0.039114
# 3          0.037511
# 4          0.027224
# ..              ...
# 538        0.000000
# 539        0.000000
# 540        0.000000
# 541        0.000000
# 542        0.000000
#
# [538 rows x 6 columns]

# %%
K = 10

# FOR TIMESERIES DF
fmt = '%Y-%m-%d %H:%M:%S %z'
df = pd.read_csv('data/processed/time_series_hour_country.csv')
df.Date = pd.to_datetime(df.Date.str[:-4], format=fmt).dt.tz_convert(None)
df = (
    df
    .groupby(['NetacqCountry', 'Date'], group_keys=False)['Volume']
    .sum()
    .reset_index()
)

top_K_countries = df.groupby('NetacqCountry')['Volume'].sum().sort_values(ascending=False)[:K].index

df = df[df.NetacqCountry.isin(top_K_countries)][['Date', 'NetacqCountry', 'Volume']]

t = df.groupby('NetacqCountry',group_keys=False)['Volume'].sum()

df['ScaledVolume'] = (
    df
    .groupby('NetacqCountry',group_keys=False)['Volume']
    .apply(lambda x: x / x.sum())
)

df['RelativeVolume'] = df['Volume'] / df['Volume'].sum()

fig, axes = plt.subplots(2,1, figsize=(6,9))

fig.suptitle('Darknet traffic by origin country over time')

for axis, column, title in zip(
    axes,
    ['ScaledVolume', 'RelativeVolume'],
    ['Scaled per-country', 'Scaled by total volume']
):
    sns.lineplot(
        ax=axis,
        data = df,
        x='Date',
        y=column,
        hue='NetacqCountry',
    )
    
    axis.set_title(title)
    axis.set_xticks(axis.get_xticks())
    axis.set_xticklabels([f'{i.get_text()[5:]}' for i in axis.get_xticklabels()])
    sns.despine(ax=axis)
    axis.legend()

# %%
df['Hour'] = df.Date.dt.hour
ax = sns.lineplot(
    data = df,
    x='Hour',
    y='ScaledVolume',
    hue='NetacqCountry',
    errorbar=None,
)

ax.set_title('Darknet Traffic Over Hour-of-day stratified by country of origin')
sns.despine()

# %% [markdown]
# # Question 3

# %%
df = pd.read_csv('data/processed/scanning_campaign.csv').dropna()


# part a
(df.groupby('Scanner')['Volume'].sum()).sort_values(ascending=False)
# (df.groupby('Scanner')['RelativeVolume'].sum() / df['RelativeVolume'].sum()).sort_values(ascending=False)
# Out:
# Scanner
# Masscan                     383675774
# ZMap                        122227678
# Mirai                       104116850
# censys-io                    60515145
# shadowserver.org             16089560
# stretchoid.com               11537272
# internet-measurement-com      7648560
# shodan-io                     5998108
# internet-census               4167915
# Bogon                           32154
# rapid7                          30720
# Name: Volume, dtype: int64

# %%
# part b
df[~df.Scanner.isin(['Mirai', 'ZMap', 'Masscan'])].groupby('Scanner')[['Protocol', 'Port']].size()
# Out:
# Scanner
# Bogon                           3
# censys-io                   64003
# internet-census              1266
# internet-measurement-com     3716
# rapid7                          2
# shadowserver.org              112
# shodan-io                    1259
# stretchoid.com                271
# dtype: int64

# %%
(
    df
    [df.Scanner.isin(['Mirai', 'ZMap', 'Masscan'])]
    .groupby(['Scanner', 'Protocol'])
    .apply(lambda x: x.nlargest(3,'Count'))
    .set_index(['Scanner', 'Protocol', 'Port'])
)
# Out:
#                          Count    Volume  RelativeCount  RelativeVolume
# Scanner Protocol Port
# Masscan TCP      3389   110207   6613584       0.003240        0.002245
#                  2375    62448   3746880       0.001836        0.001272
#                  4200    52958   3177480       0.001557        0.001079
# Mirai   TCP      23    1466375  87985098       0.043105        0.029865
#                  22     174022  10441374       0.005115        0.003544
#                  2323    63810   3828848       0.001876        0.001300
# ZMap    TCP      8443   224475  13468500       0.006599        0.004572
#                  22     211220  12673204       0.006209        0.004302
#                  5555   104221   6253260       0.003064        0.002123
#         UDP      123     22812   3703159       0.000671        0.001257
#                  53      20581   1671735       0.000605        0.000567
#                  161      6332    545811       0.000186        0.000185

# %%
df[df.Scanner == 'Mirai']
# Out:
#        Scanner Protocol   Port    Count    Volume  RelativeCount  \
# 1        Mirai      TCP     23  1466375  87985098       0.043105
# 4        Mirai      TCP     22   174022  10441374       0.005115
# 8        Mirai      TCP   2323    63810   3828848       0.001876
# 38       Mirai      TCP   5555     8482    509700       0.000249
# 92       Mirai      TCP     80     4293    257580       0.000126
# ...        ...      ...    ...      ...       ...            ...
# 107911   Mirai      TCP  58968        1        60       0.000000
# 107917   Mirai      TCP  20190        1        60       0.000000
# 107932   Mirai      TCP  15813        1        60       0.000000
# 107958   Mirai      TCP  57963        1        60       0.000000
# 107993   Mirai      TCP   3784        1        60       0.000000
#
#         RelativeVolume
# 1             0.029865
# 4             0.003544
# 8             0.001300
# 38            0.000173
# 92            0.000087
# ...                ...
# 107911        0.000000
# 107917        0.000000
# 107932        0.000000
# 107958        0.000000
# 107993        0.000000
#
# [549 rows x 7 columns]

# %% [markdown]
# # Question 4

# %%
df = pd.read_csv('data/processed/internet_backscatter.csv')

as_numbers = io.StringIO()
as_org = io.StringIO()

with gzip.open('data/20230101.as-org2info.txt.gz') as f:
    while (line:=f.readline().decode('utf-8')):
        if 'format:' in line:
            as_org.write(line.replace('# format:', ''))
            break

    while (line:=f.readline().decode('utf-8')):
        if 'format:' in line:
            as_numbers.write(line.replace('# format:', ''))
            break
        as_org.write(line)

    while (line:=f.readline().decode('utf-8')):
        as_numbers.write(line)

    as_org.seek(0)
    as_numbers.seek(0)

as_orgs = pd.read_csv(as_org, delimiter='|')
as_numbers = pd.read_csv(as_numbers, delimiter='|')

as_org_data = as_orgs.merge(as_numbers, on='org_id', suffixes=['_org', '_number'])

grouped_df = df.groupby('ASN')[['Count', 'Volume']].sum().reset_index()
grouped_df['ASN'] = grouped_df['ASN'].astype(int)
grouped_df['RelativeCount'] = grouped_df['Count'] /  grouped_df['Count'].sum()
grouped_df['RelativeVolume'] = grouped_df['Volume'] /  grouped_df['Volume'].sum()

merged_df = grouped_df.merge(as_org_data, left_on='ASN', right_on='aut')

print(
    merged_df
    .sort_values('RelativeVolume', ascending=False)[:10]
    .set_index('ASN')
    [['Volume', 'RelativeVolume', 'org_name', 'country']]
    .style.to_latex()
)


def coalesce_into_other(df, colname, K):
    return pd.concat([
        df.sort_values(colname, ascending=False).iloc[:K][['org_name','ASN', colname]],
        pd.DataFrame(columns=[colname, 'org_name', 'ASN'], 
                  data = [[
                      df.sort_values(colname, ascending=False).iloc[15:][colname].sum(),
                      'Other',
                      'Other'
                  ]])
    ])

fig, ax = plt.subplots(figsize=(7,7), dpi=300)
sns.barplot(
    data = coalesce_into_other(merged_df, 'RelativeVolume', 10), 
    # data = grouped_df.sort_values('RelativeVolume', ascending=False).iloc[:10], 
    y='ASN', 
    x='RelativeVolume',     
)

name_len = 15
ax.set_yticklabels([
    org[:name_len] + ('...' if len(org) > name_len else '') 
    for org 
    in coalesce_into_other(merged_df, 'RelativeVolume', 10).org_name.to_list()
])

ax.set_ylabel('Organization Name')
ax.set_xlabel('Relative Volume')

ax.set_title('Victims of Random-Spoof DDoS Attacks')

sns.despine()

df.dropna()[:10]
# Out:
# \begin{tabular}{lrrll}
#  & Volume & RelativeVolume & org_name & country \\
# ASN &  &  &  &  \\
# 15169 & 19770575 & 0.294026 & Google LLC & US \\
# 16509 & 5535576 & 0.082325 & Amazon.com, Inc. & US \\
# 20940 & 4936170 & 0.073410 & Akamai International B.V. & NL \\
# 9121 & 4806504 & 0.071482 & Turk Telekomunikasyon Anonim Sirketi & TR \\
# 32934 & 4033404 & 0.059984 & Facebook, Inc. & US \\
# 14618 & 3484274 & 0.051818 & Amazon.com, Inc. & US \\
# 140096 & 2019003 & 0.030026 & Shanghai Huajuan Information Technology Co., Ltd. & CN \\
# 38193 & 1942780 & 0.028893 & TRANSWORLD ASSOCIATES (PVT) LIMITED & PK \\
# 396982 & 1650252 & 0.024542 & Google LLC & US \\
# 48090 & 1587200 & 0.023605 & PPTECHNOLOGY LIMITED & GB \\
# \end{tabular}
#             dest_ip     ASN  Count   Volume  RelativeCount  RelativeVolume
# 1           8.8.4.4   15169  30332  1840246       0.000892        0.000625
# 2           8.8.8.8   15169  25688  1571416       0.000755        0.000533
# 3   142.250.181.174   15169  17142  1050257       0.000504        0.000356
# 4   142.250.201.142   15169  16466  1020302       0.000484        0.000346
# 5     157.240.227.1   32934  13244   848263       0.000389        0.000288
# 6      45.148.10.81   48090  12800  1320960       0.000376        0.000448
# 7     185.155.208.1  205607  11729   703740       0.000345        0.000239
# 8    172.217.18.131   15169  11651   714474       0.000342        0.000243
# 9    34.107.166.226   15169  10708   706728       0.000315        0.000240
# 10   157.240.227.61   32934  10102  1023754       0.000297        0.000347
